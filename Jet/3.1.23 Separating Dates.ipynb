# %%
import pandas as pd

# %%
data = pd.read_csv('dns_oct-jan.csv', parse_dates=True)
# Out:
#    shieldid         day                                          dns_qname  \
# 0  ajkerabo  2022-11-01                       104422-22.chat.api.drift.com
# 1  ajkerabo  2022-12-31                   11.au.download.windowsupdate.com
# 2  ajkerabo  2022-10-07  569c0a1f72747e0eb7ce1c550cb03bbc.fp.measure.of...
# 3  ajkerabo  2022-11-02                                aadcdn.msftauth.net
# 4  ajkerabo  2022-10-31                       accounts.platform.intuit.com
#
#      dns_qdomainname  num_clients  num_responses            timefirstseen  \
# 0          drift.com            1              8  2022-11-01 16:07:01.510
# 1  windowsupdate.com            1              2  2022-12-31 08:31:47.766
# 2         office.com            1             12  2022-10-07 12:42:17.001
# 3       msftauth.net            2              3  2022-11-02 16:57:37.825
# 4         intuit.com            1             16  2022-10-31 18:23:55.684
#
#               timelastseen
# 0  2022-11-01 16:07:01.510
# ...

# %%
data['day'] = pd.to_datetime(data['day'])

# %%
data.head()
# Out:
#             shieldid                                          dns_qname  \
# day
# 2022-11-01  ajkerabo                       104422-22.chat.api.drift.com
# 2022-12-31  ajkerabo                   11.au.download.windowsupdate.com
# 2022-10-07  ajkerabo  569c0a1f72747e0eb7ce1c550cb03bbc.fp.measure.of...
# 2022-11-02  ajkerabo                                aadcdn.msftauth.net
# 2022-10-31  ajkerabo                       accounts.platform.intuit.com
#
#               dns_qdomainname  num_clients  num_responses  \
# day
# 2022-11-01          drift.com            1              8
# 2022-12-31  windowsupdate.com            1              2
# 2022-10-07         office.com            1             12
# 2022-11-02       msftauth.net            2              3
# 2022-10-31         intuit.com            1             16
#
#                       timefirstseen             timelastseen
# day
# 2022-11-01  2022-11-01 16:07:01.510  2022-11-01 16:07:01.510
# ...

# %%
data['10-01-2022':'10-20-2022']
# Out:
#             shieldid                                          dns_qname  \
# day
# 2022-10-07  ajkerabo  569c0a1f72747e0eb7ce1c550cb03bbc.fp.measure.of...
# 2022-10-11  ajkerabo                               activity.windows.com
# 2022-10-14  ajkerabo                                 cm.everesttech.net
# 2022-10-20  ajkerabo                                cstat.cdn-apple.com
# 2022-10-18  ajkerabo                   eventinggateway-b.api.intuit.com
# ...              ...                                                ...
# 2022-10-19  zicudiva  x2.c.lencr.org.x.5734c8af0c83904b490b80804fe41...
# 2022-10-06  zicudiva  x2.c.lencr.org.x.892f20f60429504bf60b994054573...
# 2022-10-06  zicudiva  x2.c.lencr.org.x.a8be30e5069f404f17098f3061fc3...
# 2022-10-11  zicudiva  x2.c.lencr.org.x.aabfe1ae0093804cec0899d097ed8...
# 2022-10-04  zicudiva  x2.c.lencr.org.x.eac44390075f1048640bfba05443d...
#
#             dns_qdomainname  num_clients  num_responses  \
# day
# ...

# %%
data['10-01-2022':'10-20-2022'].to_csv('set1.csv')
data['10-15-2022':'11-05-2022'].to_csv('set2.csv')
data['11-01-2022':'11-20-2022'].to_csv('set3.csv')
data['11-15-2022':'12-05-2022'].to_csv('set4.csv')
data['12-01-2022':'12-20-2022'].to_csv('set5.csv')

# %%
data['12-15-2022':'01-15-2023'].to_csv('set6.csv')
