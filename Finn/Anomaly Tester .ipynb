# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# %%
path = 'dns_oct-jan.csv'
data = pd.read_csv(path)
data['day'] = pd.to_datetime(data.day)
data = data[['shieldid', 'day', 'dns_qname', 'dns_qdomainname', 'num_clients', 'num_responses']]
data
# Out:
#           shieldid        day  \
# 0         ajkerabo 2022-11-01
# 1         ajkerabo 2022-12-31
# 2         ajkerabo 2022-10-07
# 3         ajkerabo 2022-11-02
# 4         ajkerabo 2022-10-31
# ...            ...        ...
# 47100086  zicudiva 2022-10-06
# 47100087  zicudiva 2022-10-06
# 47100088  zicudiva 2022-10-11
# 47100089  zicudiva 2022-10-04
# 47100090  zicudiva 2022-11-17
#
#                                                   dns_qname  \
# 0                              104422-22.chat.api.drift.com
# 1                          11.au.download.windowsupdate.com
# 2         569c0a1f72747e0eb7ce1c550cb03bbc.fp.measure.of...
# 3                                       aadcdn.msftauth.net
# 4                              accounts.platform.intuit.com
# ...                                                     ...
# 47100086  x2.c.lencr.org.x.892f20f60429504bf60b994054573...
# 47100087  x2.c.lencr.org.x.a8be30e5069f404f17098f3061fc3...
# 47100088  x2.c.lencr.org.x.aabfe1ae0093804cec0899d097ed8...
# 47100089  x2.c.lencr.org.x.eac44390075f1048640bfba05443d...
# 47100090                          yt3.googleusercontent.com
#
#                 dns_qdomainname  num_clients  num_responses
# 0                     drift.com            1              8
# 1             windowsupdate.com            1              2
# 2                    office.com            1             12
# 3                  msftauth.net            2              3
# 4                    intuit.com            1             16
# ...                         ...          ...            ...
# 47100086            opendns.com            1              2
# 47100087            opendns.com            1              2
# 47100088            opendns.com            1              2
# 47100089            opendns.com            1              2
# 47100090  googleusercontent.com            1              1
#
# [47100091 rows x 6 columns]

# %%
df1 = data.groupby(by=['dns_qdomainname','day']).sum()
df2 = data.groupby(by=['dns_qdomainname','day'])['dns_qname'].nunique()
df2 = pd.DataFrame(df2)
df2.rename(columns={'dns_qname': 'num_dns_qname'}, inplace=True)

# %%
df = pd.concat([df1, df2], axis=1)
df.reset_index(level=1, inplace=True)
df
# Out:
#                                                           day  num_clients  \
# dns_qdomainname
# *google.com                                        2022-10-02            1
# *google.com                                        2022-10-03            1
# *google.com                                        2022-10-04            1
# *google.com                                        2022-10-10            1
# *google.com                                        2022-10-11            3
# ...                                                       ...          ...
# zzzzzzz1000.ph                                     2022-12-15            1
# zzzzzzzzz.com                                      2022-12-29            1
# zzzzzzzzzzzzzzzzzz.com                             2022-12-28            1
# zzzzzzzzzzzzzzzzzz.com                             2023-01-05            1
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz... 2023-01-19            1
#
#                                                     num_responses  \
# dns_qdomainname
# *google.com                                                     2
# *google.com                                                     2
# *google.com                                                     2
# *google.com                                                     1
# *google.com                                                   115
# ...                                                           ...
# zzzzzzz1000.ph                                                  1
# zzzzzzzzz.com                                                   2
# zzzzzzzzzzzzzzzzzz.com                                          2
# zzzzzzzzzzzzzzzzzz.com                                          2
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz...              1
#
#                                                     num_dns_qname
# dns_qdomainname
# *google.com                                                     1
# *google.com                                                     1
# *google.com                                                     1
# *google.com                                                     1
# *google.com                                                     1
# ...                                                           ...
# zzzzzzz1000.ph                                                  1
# zzzzzzzzz.com                                                   1
# zzzzzzzzzzzzzzzzzz.com                                          1
# zzzzzzzzzzzzzzzzzz.com                                          1
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz...              1
#
# [14440744 rows x 4 columns]

# %%
df1 = data.groupby(by=['dns_qdomainname','day','shieldid']).sum()
df2 = data.groupby(by=['dns_qdomainname','day','shieldid'])['dns_qname'].nunique()
df2 = pd.DataFrame(df2)
df2.rename(columns={'dns_qname': 'num_dns_qname'}, inplace=True)
newdf = pd.concat([df1, df2], axis=1)
newdf.reset_index(level=1, inplace=True)

# %%
newdf.reset_index(level=1, inplace=True)

# %%
newdf
# Out:
#                                                       shieldid        day  \
# dns_qdomainname
# *google.com                                          myakitjit 2022-10-02
# *google.com                                          myakitjit 2022-10-03
# *google.com                                          nimchulha 2022-10-04
# *google.com                                         thewseanwi 2022-10-10
# *google.com                                          nimchulha 2022-10-11
# ...                                                        ...        ...
# zzzzzzz1000.ph                                       haddomyev 2022-12-15
# zzzzzzzzz.com                                        haddomyev 2022-12-29
# zzzzzzzzzzzzzzzzzz.com                               haddomyev 2022-12-28
# zzzzzzzzzzzzzzzzzz.com                               haddomyev 2023-01-05
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz...   haddomyev 2023-01-19
#
#                                                     num_clients  \
# dns_qdomainname
# *google.com                                                   1
# *google.com                                                   1
# *google.com                                                   1
# *google.com                                                   1
# *google.com                                                   1
# ...                                                         ...
# zzzzzzz1000.ph                                                1
# zzzzzzzzz.com                                                 1
# zzzzzzzzzzzzzzzzzz.com                                        1
# zzzzzzzzzzzzzzzzzz.com                                        1
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz...            1
#
#                                                     num_responses  \
# dns_qdomainname
# *google.com                                                     2
# *google.com                                                     2
# *google.com                                                     2
# *google.com                                                     1
# *google.com                                                   110
# ...                                                           ...
# zzzzzzz1000.ph                                                  1
# zzzzzzzzz.com                                                   2
# zzzzzzzzzzzzzzzzzz.com                                          2
# zzzzzzzzzzzzzzzzzz.com                                          2
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz...              1
#
#                                                     num_dns_qname
# dns_qdomainname
# *google.com                                                     1
# *google.com                                                     1
# *google.com                                                     1
# *google.com                                                     1
# *google.com                                                     1
# ...                                                           ...
# zzzzzzz1000.ph                                                  1
# zzzzzzzzz.com                                                   1
# zzzzzzzzzzzzzzzzzz.com                                          1
# zzzzzzzzzzzzzzzzzz.com                                          1
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz...              1
#
# [19309840 rows x 5 columns]

# %%
domain = 'yourownbackyardpodcast.com' #change this domain name to test if it is an anomaly. 
dfdomain = newdf.loc[(newdf.index==domain)]
dfdomain['ratio'] = dfdomain.num_responses/dfdomain.num_clients
# Out:
# C:\Users\jack.schwaiger\AppData\Local\Temp\ipykernel_7200\3272866425.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfdomain['ratio'] = dfdomain.num_responses/dfdomain.num_clients

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Date', fontsize=15)
plt.ylabel('Responses', fontsize=15)
plt.title(domain)
for i in range(dfdomain.shieldid.nunique()):
    # data points
    shield = list(dfdomain.shieldid.unique())[i]
    plt.scatter(dfdomain.loc[dfdomain.shieldid==shield].day,dfdomain.loc[dfdomain.shieldid==shield].num_responses)

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Date', fontsize=15)
plt.ylabel('Shieldid', fontsize=15)
plt.title(domain)
plt.scatter(dfdomain.day, dfdomain.shieldid, s=dfdomain.ratio)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
